# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.stats as st
import random
import seaborn as sns

# %%
#Data is imported and checked the variables

df5_path= pd.read_csv("C:/Users/ouzgr/OneDrive/Masaüstü/data for project/2018.csv") 
df6_path= pd.read_csv("C:/Users/ouzgr/OneDrive/Masaüstü/data for project/2019.csv")
df7_path= pd.read_csv("C:/Users/ouzgr/OneDrive/Masaüstü/data for project/2020.csv")
df8_path= pd.read_csv("C:/Users/ouzgr/OneDrive/Masaüstü/data for project/2021.csv")

#frames = [df5, df6, df7,df8,df9]
#df = pd.concat(frames)

# %%
df7_path.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual', 'Year'],
#       dtype='object')

# %%
df7_path.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 21 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                153 non-null    object
#  1   Regional indicator                          153 non-null    object
#  2   Ladder score                                153 non-null    float64
#  3   Standard error of ladder score              153 non-null    float64
#  4   upperwhisker                                153 non-null    float64
#  5   lowerwhisker                                153 non-null    float64
#  6   Logged GDP per capita                       153 non-null    float64
#  7   Social support                              153 non-null    float64
#  8   Healthy life expectancy                     153 non-null    float64
# ...

# %%
df_2020 = df7_path[["Country name","Logged GDP per capita", "Social support", "Healthy life expectancy",
       "Freedom to make life choices", "Generosity","Ladder score",
       "Perceptions of corruption","Year"]]

# %%
df_2020.head()
# Out:
#   Country name  Logged GDP per capita  Social support  \
# 0      Finland              10.639267        0.954330
# 1      Denmark              10.774001        0.955991
# 2  Switzerland              10.979933        0.942847
# 3      Iceland              10.772559        0.974670
# 4       Norway              11.087804        0.952487
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                71.900825                      0.949172   -0.059482
# 1                72.402504                      0.951444    0.066202
# 2                74.102448                      0.921337    0.105911
# 3                73.000000                      0.948892    0.246944
# 4                73.200783                      0.955750    0.134533
#
#    Ladder score  Perceptions of corruption  Year
# 0        7.8087                   0.195445  2020
# 1        7.6456                   0.168489  2020
# 2        7.5599                   0.303728  2020
# ...

# %%
df5_path.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Year'],
#       dtype='object')

# %%
df_2018 = df5_path[['Country or region', 'Score', 'GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption','Year']]

# %%
df6_path.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Year'],
#       dtype='object')

# %%
df_2019 = df6_path[['Country or region', 'Score', 'GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption','Year']]

# %%
df8_path.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual', 'Year'],
#       dtype='object')

# %%
df_2021 = df8_path[['Country name', 'Ladder score', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption','Year']]

# %%
#As we have long column names, i will change some of them 
df_2021_renamed= df_2021.rename(columns = {'Country name':'Country or region' ,'Ladder score':'Score', 'Logged GDP per capita':'GDP per capita'})
df_2021_renamed.head()
# Out:
#   Country or region  Score  GDP per capita  Social support  \
# 0           Finland  7.842          10.775           0.954
# 1           Denmark  7.620          10.933           0.954
# 2       Switzerland  7.571          11.117           0.942
# 3           Iceland  7.554          10.878           0.983
# 4       Netherlands  7.464          10.932           0.942
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                     72.0                         0.949      -0.098
# 1                     72.7                         0.946       0.030
# 2                     74.4                         0.919       0.025
# 3                     73.0                         0.955       0.160
# 4                     72.4                         0.913       0.175
#
#    Perceptions of corruption  Year
# 0                      0.186  2021
# 1                      0.179  2021
# 2                      0.292  2021
# 3                      0.673  2021
# ...

# %%
df_2020_renamed= df_2020.rename(columns = {'Country name':'Country or region' ,'Ladder score':'Score', 'Logged GDP per capita':'GDP per capita'})
df_2020_renamed.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland       10.639267        0.954330                71.900825
# 1           Denmark       10.774001        0.955991                72.402504
# 2       Switzerland       10.979933        0.942847                74.102448
# 3           Iceland       10.772559        0.974670                73.000000
# 4            Norway       11.087804        0.952487                73.200783
#
#    Freedom to make life choices  Generosity   Score  \
# 0                      0.949172   -0.059482  7.8087
# 1                      0.951444    0.066202  7.6456
# 2                      0.921337    0.105911  7.5599
# 3                      0.948892    0.246944  7.5045
# 4                      0.955750    0.134533  7.4880
#
#    Perceptions of corruption  Year
# 0                   0.195445  2020
# 1                   0.168489  2020
# 2                   0.303728  2020
# 3                   0.711710  2020
# ...

# %%
#Check last 5 values of the data 
df_2018.tail()
# Out:
#             Country or region  Score  GDP per capita  Social support  \
# 151                     Yemen  3.355           0.442           1.073
# 152                  Tanzania  3.303           0.455           0.991
# 153               South Sudan  3.254           0.337           0.608
# 154  Central African Republic  3.083           0.024           0.000
# 155                   Burundi  2.905           0.091           0.627
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 151                    0.343                         0.244       0.083
# 152                    0.381                         0.481       0.270
# 153                    0.177                         0.112       0.224
# 154                    0.010                         0.305       0.218
# 155                    0.145                         0.065       0.149
#
#      Perceptions of corruption  Year
# 151                      0.064  2018
# 152                      0.097  2018
# ...

# %%
#Check last 5 values of the data 
df_2019.tail()
# Out:
#             Country or region  Score  GDP per capita  Social support  \
# 151                    Rwanda  3.334           0.359           0.711
# 152                  Tanzania  3.231           0.476           0.885
# 153               Afghanistan  3.203           0.350           0.517
# 154  Central African Republic  3.083           0.026           0.000
# 155               South Sudan  2.853           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 151                    0.614                         0.555       0.217
# 152                    0.499                         0.417       0.276
# 153                    0.361                         0.000       0.158
# 154                    0.105                         0.225       0.235
# 155                    0.295                         0.010       0.202
#
#      Perceptions of corruption  Year
# 151                      0.411  2019
# 152                      0.147  2019
# ...

# %%
#Check last 5 values of the data 
df_2020_renamed.tail()
# Out:
#             Country or region  GDP per capita  Social support  \
# 148  Central African Republic        6.625160        0.319460
# 149                    Rwanda        7.600104        0.540835
# 150                  Zimbabwe        7.865712        0.763093
# 151               South Sudan        7.425360        0.553707
# 152               Afghanistan        7.462861        0.470367
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 148                45.200001                      0.640881    0.082410
# 149                61.098846                      0.900589    0.055484
# 150                55.617260                      0.711458   -0.072064
# 151                51.000000                      0.451314    0.016519
# 152                52.590000                      0.396573   -0.096429
#
#       Score  Perceptions of corruption  Year
# 148  3.4759                   0.891807  2020
# 149  3.3123                   0.183541  2020
# ...

# %% [markdown]
# ## Check last 5 values of the data
# df_2021_renamed.tail()

# %%
combined_countries = pd.concat([df_2018,df_2019,df_2020_renamed,df_2021_renamed])
combined_countries.tail(149)
# Out:
#     Country or region  Score  GDP per capita  Social support  \
# 0             Finland  7.842          10.775           0.954
# 1             Denmark  7.620          10.933           0.954
# 2         Switzerland  7.571          11.117           0.942
# 3             Iceland  7.554          10.878           0.983
# 4         Netherlands  7.464          10.932           0.942
# ..                ...    ...             ...             ...
# 144           Lesotho  3.512           7.926           0.787
# 145          Botswana  3.467           9.782           0.784
# 146            Rwanda  3.415           7.676           0.552
# 147          Zimbabwe  3.145           7.943           0.750
# 148       Afghanistan  2.523           7.695           0.463
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                     72.000                         0.949      -0.098
# 1                     72.700                         0.946       0.030
# ...

# %%
# Out:
#             Score  GDP per capita  Social support  Healthy life expectancy  \
# count  614.000000      614.000000      614.000000               614.000000
# mean     5.446171        5.061744        1.014611                32.166803
# std      1.104113        4.324451        0.304179                32.412930
# min      2.523000        0.000000        0.000000                 0.000000
# 25%      4.628750        0.951500        0.810250                 0.691500
# 50%      5.461100        1.574000        0.922247                 1.048500
# 75%      6.198750        9.482750        1.268750                66.303859
# max      7.842000       11.647000        1.644000                76.953000
#
#        Freedom to make life choices  Generosity  Perceptions of corruption  \
# count                    614.000000  614.000000                 613.000000
# mean                       0.602518    0.085650                   0.416267
# ...

# %%
combined_countries_without_year = combined_countries[['Country or region', 'Score', 'GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']]

# %%
combined_countries_without_year.describe()
# Out:
#             Score  GDP per capita  Social support  Healthy life expectancy  \
# count  614.000000      614.000000      614.000000               614.000000
# mean     5.446171        5.061744        1.014611                32.166803
# std      1.104113        4.324451        0.304179                32.412930
# min      2.523000        0.000000        0.000000                 0.000000
# 25%      4.628750        0.951500        0.810250                 0.691500
# 50%      5.461100        1.574000        0.922247                 1.048500
# 75%      6.198750        9.482750        1.268750                66.303859
# max      7.842000       11.647000        1.644000                76.953000
#
#        Freedom to make life choices  Generosity  Perceptions of corruption
# count                    614.000000  614.000000                 613.000000
# mean                       0.602518    0.085650                   0.416267
# ...

# %%
combined_countries.to_csv('Happiness.csv',index=False)
